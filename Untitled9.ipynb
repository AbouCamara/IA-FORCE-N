# %% [markdown]
# <a href="https://colab.research.google.com/github/AbouCamara/IA-FORCE-N/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
import io
uploaded= files.upload()
# Out:
#      <input type="file" id="files-6ba24d97-1010-47d9-b2e4-d290a327cb0d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ba24d97-1010-47d9-b2e4-d290a327cb0d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df= pd.read_csv(io.BytesIO(uploaded['apts.csv']))

# %%
df
# Out:
#      sexe  age  taille  poids
# 0       1  147  151.13  45.80
# 1       0  160  150.62  35.60
# 2       1  148  149.86  43.08
# 3       0  149  144.78  41.72
# 4       0  156  156.21  49.21
# ..    ...  ...     ...    ...
# 232     1  178  156.21  46.94
# 233     1  166  150.62  40.59
# 234     1  193  151.89  52.15
# 235     0  166  158.75  38.10
# 236     1  165  140.97  30.39
#
# [237 rows x 4 columns]

# %%
df.shape
# Out:
# (237, 4)

# %%
df.columns
# Out:
# Index(['sexe', 'age', 'taille', 'poids'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sexe    237 non-null    int64
#  1   age     237 non-null    int64
#  2   taille  237 non-null    float64
#  3   poids   237 non-null    float64
# dtypes: float64(2), int64(2)
# memory usage: 7.5 KB

# %%
df.head(10)
# Out:
#    sexe  age  taille  poids
# 0     1  147  151.13  45.80
# 1     0  160  150.62  35.60
# 2     1  148  149.86  43.08
# 3     0  149  144.78  41.72
# 4     0  156  156.21  49.21
# 5     0  177  160.02  50.34
# 6     1  169  157.48  44.67
# 7     0  189  170.18  58.05
# 8     1  197  156.21  54.88
# 9     0  145  143.51  41.27

# %%
df.tail()
# Out:
#      sexe  age  taille  poids
# 232     1  178  156.21  46.94
# 233     1  166  150.62  40.59
# 234     1  193  151.89  52.15
# 235     0  166  158.75  38.10
# 236     1  165  140.97  30.39

# %%
df[['age','poids']]
# Out:
#      age  poids
# 0    147  45.80
# 1    160  35.60
# 2    148  43.08
# 3    149  41.72
# 4    156  49.21
# ..   ...    ...
# 232  178  46.94
# 233  166  40.59
# 234  193  52.15
# 235  166  38.10
# 236  165  30.39
#
# [237 rows x 2 columns]

# %%
x= df[['age','sexe']]

# %%
x
# Out:
#      age  sexe
# 0    147     1
# 1    160     0
# 2    148     1
# 3    149     0
# 4    156     0
# ..   ...   ...
# 232  178     1
# 233  166     1
# 234  193     1
# 235  166     0
# 236  165     1
#
# [237 rows x 2 columns]

# %%
x['sexe'].value_counts()
# Out:
# sexe
# 0    126
# 1    111
# Name: count, dtype: int64

# %%
df['SEXE'].value_counts()
# Out:
# SEXE
# 0    126
# 1    111
# Name: count, dtype: int64

# %%
df.iloc[2:7]
# Out:
#    sexe  age  taille  poids
# 2     1  148  149.86  43.08
# 3     0  149  144.78  41.72
# 4     0  156  156.21  49.21
# 5     0  177  160.02  50.34
# 6     1  169  157.48  44.67

# %%
df.columns=[x.upper() for x in df.columns]
df.head()
# Out:
#    SEXE  AGE  TAILLE  POIDS
# 0     1  147  151.13  45.80
# 1     0  160  150.62  35.60
# 2     1  148  149.86  43.08
# 3     0  149  144.78  41.72
# 4     0  156  156.21  49.21

# %%
df['SEXE']=df['SEXE'].map({0:'F',1:'M'})

# %%
df.head(10)
# Out:
#   SEXE  AGE  TAILLE  POIDS
# 0    M  147  151.13  45.80
# 1    F  160  150.62  35.60
# 2    M  148  149.86  43.08
# 3    F  149  144.78  41.72
# 4    F  156  156.21  49.21
# 5    F  177  160.02  50.34
# 6    M  169  157.48  44.67
# 7    F  189  170.18  58.05
# 8    M  197  156.21  54.88
# 9    F  145  143.51  41.27

# %%
df['SEXE'].value_counts()
# Out:
# SEXE
# F    126
# M    111
# Name: count, dtype: int64
